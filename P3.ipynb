# %% [markdown]
# # Réalisez une étude santé publique

# %%
## Question 1

# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = []

# %%
df1 = pd.read_csv("Q1.csv", usecols = ["Pays", "Valeur"])

# %%
df1
# Out:
#                                        Pays   Valeur
# 0                               Afghanistan    30552
# 1                            Afrique du Sud    52776
# 2                                   Albanie     3173
# 3                                   Algérie    39208
# 4                                 Allemagne    82727
# 5                                    Angola    21472
# 6                        Antigua-et-Barbuda       90
# 7                           Arabie saoudite    28829
# 8                                 Argentine    41446
# 9                                   Arménie     2977
# 10                                Australie    23343
# 11                                 Autriche     8495
# 12                              Azerbaïdjan     9413
# 13                                  Bahamas      377
# 14                               Bangladesh   156595
# 15                                  Barbade      285
# 16                                  Bélarus     9357
# 17                                 Belgique    11104
# 18                                   Belize      332
# 19                                    Bénin    10323
# 20                                 Bermudes       65
# 21          Bolivie (État plurinational de)    10671
# 22                       Bosnie-Herzégovine     3829
# 23                                 Botswana     2021
# 24                                   Brésil   200362
# 25                        Brunéi Darussalam      418
# 26                                 Bulgarie     7223
# 27                             Burkina Faso    16935
# 28                               Cabo Verde      499
# 29                                 Cambodge    15135
# ..                                      ...      ...
# 145                                 Sénégal    14133
# 146                                  Serbie     9511
# 147                            Sierra Leone     6092
# 148                               Slovaquie     5450
# 149                                Slovénie     2072
# 150                                  Soudan    37964
# 151                               Sri Lanka    21273
# 152                                   Suède     9571
# 153                                  Suisse     8078
# 154                                Suriname      539
# 155                                Eswatini     1250
# 156                             Tadjikistan     8208
# 157                                   Tchad    12825
# 158                           Tchéquie (la)    10702
# 159                               Thaïlande    67011
# 160                             Timor-Leste     1133
# 161                                    Togo     6817
# 162                       Trinité-et-Tobago     1341
# 163                                 Tunisie    10997
# 164                            Turkménistan     5240
# 165                                 Turquie    74933
# 166                                 Ukraine    45239
# 167                                 Uruguay     3407
# 168                                 Vanuatu      253
# 169  Venezuela (République bolivarienne du)    30405
# 170                                Viet Nam    91680
# 171                                   Yémen    24407
# 172                                  Zambie    14539
# 173                                Zimbabwe    14150
# 174                                   Chine  1416667
#
# [175 rows x 2 columns]

# %%
df1['Valeur'].sum() * 1000
# Out:
# 8413993000

# %% [markdown]
# - Ce chiffre est supérieur à la population mondiale officielle. Il englobe deux fois la chine continentale.

# %%
df1_wo_china = df1[df1['Pays'] != "Chine"]

# %%
mondial_pop = df1_wo_china['Valeur'].sum() * 1000
print(mondial_pop)
# Out:
# 6997326000

# %% [markdown]
# - C'est une valeur plus conforme aux chiffres officiels (Source: https://www.prb.org/wp-content/uploads/2014/02/2013-population-data-sheet_french.pdf)

# %%
temp = pd.read_csv("pop.csv")

# %%
temp.columns = ['xx','xx2','country_code','country','xx3','element'
    ,'item_code','item','xx4',"year","unit","value",'xx5','xx6']

# %%
pop = temp.pivot_table(
    index=["country_code","country","item_code","item","year"],
    columns = ["element"], values=["value"], aggfunc=sum)

# %%
pop.columns = ['total_population']

# %%
pop.reset_index()
pop.query('country == "France"')
# Out:
#                                                 total_population
# country_code country item_code item       year
# 68           France  2501      Population 2013             64291

# %% [markdown]
# ## Question 2

# %%
df2 = pd.read_csv("Q2.csv")

# %%
df2
# Out:
#    Code Domaine              Domaine  Code Pays    Pays  Code Élément  \
# 0           FBS  Bilans Alimentaires         68  France          5511
# 1           FBS  Bilans Alimentaires         68  France          5611
# 2           FBS  Bilans Alimentaires         68  France          5072
# 3           FBS  Bilans Alimentaires         68  France          5911
# 4           FBS  Bilans Alimentaires         68  France          5301
# 5           FBS  Bilans Alimentaires         68  France          5521
# 6           FBS  Bilans Alimentaires         68  France          5527
# 7           FBS  Bilans Alimentaires         68  France          5123
# 8           FBS  Bilans Alimentaires         68  France          5131
# 9           FBS  Bilans Alimentaires         68  France          5154
# 10          FBS  Bilans Alimentaires         68  France          5142
# 11          FBS  Bilans Alimentaires         68  France           645
# 12          FBS  Bilans Alimentaires         68  France           664
# 13          FBS  Bilans Alimentaires         68  France           674
# 14          FBS  Bilans Alimentaires         68  France           684
#
#                                               Élément  Code Produit Produit  \
# 0                                          Production          2511     Blé
# 1                             Importations - Quantité          2511     Blé
# 2                                  Variation de stock          2511     Blé
# 3                             Exportations - Quantité          2511     Blé
# 4                            Disponibilité intérieure          2511     Blé
# 5                               Aliments pour animaux          2511     Blé
# 6                                            Semences          2511     Blé
# 7                                              Pertes          2511     Blé
# 8                                          Traitement          2511     Blé
# 9                                 Autres Utilisations          2511     Blé
# 10                                         Nourriture          2511     Blé
# 11  Disponibilité alimentaire en quantité (kg/pers...          2511     Blé
# 12     Disponibilité alimentaire (Kcal/personne/jour)          2511     Blé
# 13  Disponibilité de protéines en quantité (g/pers...          2511     Blé
# 14  Disponibilité de matière grasse en quantité (g...          2511     Blé
#
#     Code Année  Année               Unité    Valeur Symbole  \
# 0         2013   2013  Milliers de tonnes  38614.00       S
# 1         2013   2013  Milliers de tonnes   2055.00       S
# 2         2013   2013  Milliers de tonnes   1131.00       S
# 3         2013   2013  Milliers de tonnes  21502.00       S
# 4         2013   2013  Milliers de tonnes  20298.00       S
# 5         2013   2013  Milliers de tonnes   7822.00       S
# 6         2013   2013  Milliers de tonnes    748.00       S
# 7         2013   2013  Milliers de tonnes    358.00       S
# 8         2013   2013  Milliers de tonnes   1575.00       S
# 9         2013   2013  Milliers de tonnes   2824.00       S
# 10        2013   2013  Milliers de tonnes   6971.00       S
# 11        2013   2013                  kg    108.43      Fc
# 12        2013   2013  Kcal/personne/jour    811.00      Fc
# 13        2013   2013     g/personne/jour     25.99      Fc
# 14        2013   2013     g/personne/jour      4.20      Fc
#
#    Description du Symbole
# 0   Données standardisées
# 1   Données standardisées
# 2   Données standardisées
# 3   Données standardisées
# 4   Données standardisées
# 5   Données standardisées
# 6   Données standardisées
# 7   Données standardisées
# 8   Données standardisées
# 9   Données standardisées
# 10  Données standardisées
# 11        Donnée calculée
# 12        Donnée calculée
# 13        Donnée calculée
# 14        Donnée calculée

# %% [markdown]
# - Disponibilité intérieure = Production + Importations - Exportations + Variation des stocks = Nourriture + Aliments pour animaux + Semences + Pertes + Traitement + Autres Utilisations
#
# - Nourriture / population = Disponibilité alimentaire en quantité (kg par personne par an)

# %% [markdown]
# ## Question 3

# %%
# Import des données des bilans alimentaires
veg = pd.read_csv("veg.csv")
ani = pd.read_csv("ani.csv")

# Ajout de la variable origin
ani["origin"] = "animal"
veg["origin"] = "vegetal"

# On regroupe veg et ani en un unique dataframe, via une union
temp = ani.append(veg)

# Suppression de ani et veg
del ani, veg

# On renomme les colonnes de temp
temp.columns = ["xx","xx2","country_code","country",'xx3','element'
    ,'item_code','item','xx4',"year","unit","value",'xx5','xx6'
    ,'origin']

# Transformation de temp en table pivot
data = temp.pivot_table(
    index=["country_code","country","item_code","item","year","origin"],
    columns = ["element"], values=["value"], aggfunc=sum)
# On renomme les colonnes (attention l'ordre peut changer selon vos données !)
data.columns = ['domestic_supply_quantity', 'export_quantity', 'fat_supply_quantity_gcapitaday',
    'feed', 'food', 'food_supply_kcalcapitaday', 
    'food_supply_quantity_kgcapitayr', 'import_quantity', 'waste', 'other_uses',
    'processing', 'production', 'protein_supply_quantity_gcapitaday', 
    'seed', 'stock_variation']
    
data = data.reset_index()
data.head()
# Out:
#    country_code  country  item_code                 item  year   origin  \
# 0             1  Armenia       2511   Wheat and products  2013  vegetal
# 1             1  Armenia       2513  Barley and products  2013  vegetal
# 2             1  Armenia       2514   Maize and products  2013  vegetal
# 3             1  Armenia       2515     Rye and products  2013  vegetal
# 4             1  Armenia       2516                 Oats  2013  vegetal
#
#    domestic_supply_quantity  export_quantity  fat_supply_quantity_gcapitaday  \
# 0                     554.0              1.0                            3.60
# 1                     198.0              0.0                            0.00
# 2                     102.0              NaN                             NaN
# 3                       1.0              NaN                            0.00
# 4                       6.0              NaN                            0.03
#
#     feed  ...  food_supply_kcalcapitaday  food_supply_quantity_kgcapitayr  \
# 0   93.0  ...                     1024.0                           130.60
# 1  137.0  ...                        0.0                             0.00
# 2   96.0  ...                        0.0                             0.03
# 3    1.0  ...                        1.0                             0.12
# 4    4.0  ...                        2.0                             0.37
#
#    import_quantity  waste  other_uses  processing  production  \
# 0            361.0   32.0         0.0        10.0       312.0
# 1              9.0   15.0        26.0         7.0       189.0
# 2             82.0    7.0         NaN         NaN        21.0
# 3              0.0    0.0         NaN         NaN         1.0
# 4              1.0    0.0         NaN         NaN         5.0
#
#    protein_supply_quantity_gcapitaday  seed  stock_variation
# 0                               30.52  30.0           -118.0
# 1                                0.00  14.0              0.0
# 2                                0.01   0.0              NaN
# 3                                0.02   0.0              0.0
# 4                                0.09   0.0              NaN
#
# [5 rows x 21 columns]

# %%
data = data.merge(pop, on=['country'])
data = data.replace([np.inf, -np.inf], np.nan).dropna(subset=["food_supply_kcalcapitaday"], how="all")
data = data.replace([np.inf, -np.inf], np.nan).dropna(subset=["protein_supply_quantity_gcapitaday"], how="all")
data = data.replace([np.inf, -np.inf], np.nan).dropna(subset=["food_supply_quantity_kgcapitayr"], how="all")

# %%
data['total_kcal'] = data['food_supply_kcalcapitaday'] * 365 * data['total_population'] * 1000

# %%
data['total_protein_kg'] = (data['protein_supply_quantity_gcapitaday'] / 1000) * 365 * data['total_population'] * 1000
data.head()
# Out:
#    country_code  country  item_code                 item  year   origin  \
# 0             1  Armenia       2511   Wheat and products  2013  vegetal
# 1             1  Armenia       2513  Barley and products  2013  vegetal
# 2             1  Armenia       2514   Maize and products  2013  vegetal
# 3             1  Armenia       2515     Rye and products  2013  vegetal
# 4             1  Armenia       2516                 Oats  2013  vegetal
#
#    domestic_supply_quantity  export_quantity  fat_supply_quantity_gcapitaday  \
# 0                     554.0              1.0                            3.60
# 1                     198.0              0.0                            0.00
# 2                     102.0              NaN                             NaN
# 3                       1.0              NaN                            0.00
# 4                       6.0              NaN                            0.03
#
#     feed  ...  waste  other_uses  processing  production  \
# 0   93.0  ...   32.0         0.0        10.0       312.0
# 1  137.0  ...   15.0        26.0         7.0       189.0
# 2   96.0  ...    7.0         NaN         NaN        21.0
# 3    1.0  ...    0.0         NaN         NaN         1.0
# 4    4.0  ...    0.0         NaN         NaN         5.0
#
#    protein_supply_quantity_gcapitaday  seed  stock_variation  \
# 0                               30.52  30.0           -118.0
# 1                                0.00  14.0              0.0
# 2                                0.01   0.0              NaN
# 3                                0.02   0.0              0.0
# 4                                0.09   0.0              NaN
#
#    total_population    total_kcal  total_protein_kg
# 0              2977  1.112684e+12       33163184.60
# 1              2977  0.000000e+00              0.00
# 2              2977  0.000000e+00          10866.05
# 3              2977  1.086605e+09          21732.10
# 4              2977  2.173210e+09          97794.45
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Question 4

# %%
data['kcal/kg'] = data['food_supply_kcalcapitaday'] * 365 / data['food_supply_quantity_kgcapitayr']
data.head()
# Out:
#    country_code  country  item_code                 item  year   origin  \
# 0             1  Armenia       2511   Wheat and products  2013  vegetal
# 1             1  Armenia       2513  Barley and products  2013  vegetal
# 2             1  Armenia       2514   Maize and products  2013  vegetal
# 3             1  Armenia       2515     Rye and products  2013  vegetal
# 4             1  Armenia       2516                 Oats  2013  vegetal
#
#    domestic_supply_quantity  export_quantity  fat_supply_quantity_gcapitaday  \
# 0                     554.0              1.0                            3.60
# 1                     198.0              0.0                            0.00
# 2                     102.0              NaN                             NaN
# 3                       1.0              NaN                            0.00
# 4                       6.0              NaN                            0.03
#
#     feed  ...  other_uses  processing  production  \
# 0   93.0  ...         0.0        10.0       312.0
# 1  137.0  ...        26.0         7.0       189.0
# 2   96.0  ...         NaN         NaN        21.0
# 3    1.0  ...         NaN         NaN         1.0
# 4    4.0  ...         NaN         NaN         5.0
#
#    protein_supply_quantity_gcapitaday  seed  stock_variation  \
# 0                               30.52  30.0           -118.0
# 1                                0.00  14.0              0.0
# 2                                0.01   0.0              NaN
# 3                                0.02   0.0              0.0
# 4                                0.09   0.0              NaN
#
#    total_population    total_kcal  total_protein_kg      kcal/kg
# 0              2977  1.112684e+12       33163184.60  2861.868300
# 1              2977  0.000000e+00              0.00          NaN
# 2              2977  0.000000e+00          10866.05     0.000000
# 3              2977  1.086605e+09          21732.10  3041.666667
# 4              2977  2.173210e+09          97794.45  1972.972973
#
# [5 rows x 25 columns]

# %%
temp = data[data['item'].str.contains("Eggs")]

# %%
# valeur nutritionnelle pour 100g
egg_ve = temp.replace([np.inf, -np.inf], np.nan).dropna(subset=["kcal/kg"], how="all")
egg_ve['kcal/kg'].mean()/10
# Out:
# 136.47554180345907

# %% [markdown]
# - ce chiffre est inférieur en moyenne dans le monde à la valeur de 147 kcal pour un oeuf de poule entier cru donné par Wikipedia (https://fr.wikipedia.org/wiki/Œuf_(aliment))

# %%
data['protein_percentage'] = ((data['protein_supply_quantity_gcapitaday'] * 1000 * 365) / (data['food'] * 1000000)) * 100

# %%
data.head(20)
# Out:
#     country_code  country  item_code                          item  year  \
# 0              1  Armenia       2511            Wheat and products  2013
# 1              1  Armenia       2513           Barley and products  2013
# 2              1  Armenia       2514            Maize and products  2013
# 3              1  Armenia       2515              Rye and products  2013
# 4              1  Armenia       2516                          Oats  2013
# 7              1  Armenia       2520                Cereals, Other  2013
# 8              1  Armenia       2531         Potatoes and products  2013
# 16             1  Armenia       2549    Pulses, Other and products  2013
# 17             1  Armenia       2551             Nuts and products  2013
# 19             1  Armenia       2556       Groundnuts (Shelled Eq)  2013
# 21             1  Armenia       2558          Rape and Mustardseed  2013
# 22             1  Armenia       2560         Coconuts - Incl Copra  2013
# 23             1  Armenia       2561                   Sesame seed  2013
# 24             1  Armenia       2563  Olives (including preserved)  2013
# 28             1  Armenia       2573             Sunflowerseed Oil  2013
# 37             1  Armenia       2586           Oilcrops Oil, Other  2013
# 38             1  Armenia       2601         Tomatoes and products  2013
# 39             1  Armenia       2602                        Onions  2013
# 40             1  Armenia       2605             Vegetables, Other  2013
# 41             1  Armenia       2611           Oranges, Mandarines  2013
#
#      origin  domestic_supply_quantity  export_quantity  \
# 0   vegetal                     554.0              1.0
# 1   vegetal                     198.0              0.0
# 2   vegetal                     102.0              NaN
# 3   vegetal                       1.0              NaN
# 4   vegetal                       6.0              NaN
# 7   vegetal                      21.0              0.0
# 8   vegetal                     672.0              9.0
# 16  vegetal                       3.0              0.0
# 17  vegetal                       6.0              1.0
# 19  vegetal                       1.0              0.0
# 21  vegetal                       0.0              NaN
# 22  vegetal                       0.0              0.0
# 23  vegetal                       0.0              NaN
# 24  vegetal                       3.0              1.0
# 28  vegetal                      30.0              0.0
# 37  vegetal                       2.0              0.0
# 38  vegetal                     273.0              3.0
# 39  vegetal                      53.0              0.0
# 40  vegetal                     764.0              6.0
# 41  vegetal                      14.0              1.0
#
#     fat_supply_quantity_gcapitaday   feed  ...  processing  production  \
# 0                             3.60   93.0  ...        10.0       312.0
# 1                             0.00  137.0  ...         7.0       189.0
# 2                              NaN   96.0  ...         NaN        21.0
# 3                             0.00    1.0  ...         NaN         1.0
# 4                             0.03    4.0  ...         NaN         5.0
# 7                             0.04    1.0  ...         NaN        17.0
# 8                             0.12  225.0  ...        78.0       661.0
# 16                             NaN    3.0  ...         NaN         0.0
# 17                            1.76    NaN  ...         NaN         5.0
# 19                            0.55    NaN  ...         NaN         NaN
# 21                            0.00    0.0  ...         NaN         NaN
# 22                            0.03    NaN  ...         NaN         NaN
# 23                            0.01    NaN  ...         NaN         NaN
# 24                            0.28    NaN  ...         NaN         NaN
# 28                           24.38    NaN  ...         NaN         1.0
# 37                            0.02    NaN  ...         0.0         NaN
# 38                            0.48    NaN  ...         NaN       276.0
# 39                            0.10    NaN  ...         NaN        45.0
# 40                            1.18   13.0  ...         NaN       764.0
# 41                            0.01    NaN  ...         NaN         NaN
#
#     protein_supply_quantity_gcapitaday   seed  stock_variation  \
# 0                                30.52   30.0           -118.0
# 1                                 0.00   14.0              0.0
# 2                                 0.01    0.0              NaN
# 3                                 0.02    0.0              0.0
# 4                                 0.09    0.0              NaN
# 7                                 0.39    1.0              0.0
# 8                                 1.94  123.0             15.0
# 16                                0.00    NaN              NaN
# 17                                0.42    NaN              0.0
# 19                                0.29    NaN              0.0
# 21                                0.00    NaN              NaN
# 22                                0.00    NaN              0.0
# 23                                0.00    NaN              NaN
# 24                                0.03    NaN              NaN
# 28                                0.04    NaN              0.0
# 37                                0.00    NaN              0.0
# 38                                1.94    NaN              0.0
# 39                                0.53    NaN              0.0
# 40                                6.66    NaN              0.0
# 41                                0.07    NaN              0.0
#
#     total_population    total_kcal  total_protein_kg      kcal/kg  \
# 0               2977  1.112684e+12       33163184.60  2861.868300
# 1               2977  0.000000e+00              0.00          NaN
# 2               2977  0.000000e+00          10866.05     0.000000
# 3               2977  1.086605e+09          21732.10  3041.666667
# 4               2977  2.173210e+09          97794.45  1972.972973
# 7               2977  1.521247e+10         423775.95  2607.142857
# 8               2977  8.910161e+10        2108013.70   663.636364
# 16              2977  0.000000e+00              0.00          NaN
# 17              2977  1.955889e+10         456374.10  3055.813953
# 19              2977  6.519630e+09         315115.45  5475.000000
# 21              2977  0.000000e+00              0.00          NaN
# 22              2977  0.000000e+00              0.00     0.000000
# 23              2977  0.000000e+00              0.00     0.000000
# 24              2977  3.259815e+09          32598.15  1190.217391
# 28              2977  2.347067e+11          43464.20  8908.474576
# 37              2977  0.000000e+00              0.00     0.000000
# 38              2977  4.455080e+10        2108013.70   169.863791
# 39              2977  1.629908e+10         575900.65   311.610700
# 40              2977  1.553845e+11        7236789.30   214.599951
# 41              2977  4.346420e+09          76062.35   305.439331
#
#     protein_percentage
# 0             2.863702
# 1                  NaN
# 2                  inf
# 3                  inf
# 4             3.285000
# 7             2.372500
# 8             0.528433
# 16                 NaN
# 17            2.555000
# 19           10.585000
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24            0.365000
# 28            0.056154
# 37                 NaN
# 38            0.270267
# 39            0.372019
# 40            0.335760
# 41            0.182500
#
# [20 rows x 26 columns]

# %%
temp = data[data['item'].str.contains("Oats")]

# %%
temp = temp.replace([np.inf, -np.inf], np.nan).dropna(subset=["protein_percentage"], how="all")

# %%
temp = temp[temp['protein_supply_quantity_gcapitaday'] > 0]

# %%
temp['protein_percentage'].mean()
# Out:
# 2.080560270459758

# %% [markdown]
# - La teneur en protéine de l'avoine est en moyenne de 2,1%

# %% [markdown]
# ## Question 5

# %%
temp = data.replace([np.inf, -np.inf], np.nan).dropna(subset=["kcal/kg"], how="all")
temp.pivot_table(
    index=["item_code","item","year","origin"],
    values=["kcal/kg"], aggfunc=np.mean).sort_values(by='kcal/kg', ascending=False).head(20)
# Out:
#                                                      kcal/kg
# item_code item                     year origin
# 2579      Sesameseed Oil           2013 vegetal  9559.523810
# 2582      Maize Germ Oil           2013 vegetal  8950.891229
# 2580      Olive Oil                2013 vegetal  8774.038462
# 2573      Sunflowerseed Oil        2013 vegetal  8769.634357
# 2571      Soyabean Oil             2013 vegetal  8739.687728
# 2577      Palm Oil                 2013 vegetal  8682.340531
# 2586      Oilcrops Oil, Other      2013 vegetal  8417.429666
# 2581      Ricebran Oil             2013 vegetal  8264.150943
# 2574      Rape and Mustard Oil     2013 vegetal  8238.956406
# 2578      Coconut Oil              2013 vegetal  7912.109869
# 2575      Cottonseed Oil           2013 vegetal  7708.151847
# 2576      Palmkernel Oil           2013 vegetal  7654.792329
# 2737      Fats, Animals, Raw       2013 animal   7562.536349
# 2572      Groundnut Oil            2013 vegetal  7208.090833
# 2781      Fish, Body Oil           2013 animal   7133.945055
# 2740      Butter, Ghee             2013 animal   6973.406757
# 2562      Palm kernels             2013 vegetal  5475.000000
# 2556      Groundnuts (Shelled Eq)  2013 vegetal  5466.240153
# 2561      Sesame seed              2013 vegetal  5144.359508
# 2633      Cocoa Beans and products 2013 vegetal  4342.347542

# %% [markdown]
# - Parmi les 20 aliments les plus caloriques, on peut citer toutes les huiles, les graisses animales, les cacahuètes et le beurre

# %%
temp = data.replace([np.inf, -np.inf], np.nan).dropna(subset=["protein_percentage"], how="all")
temp.pivot_table(
    index=["item_code","item","year","origin"],
    values=["protein_percentage"], aggfunc=np.mean).sort_values(by='protein_percentage', ascending=False).head(20)
# Out:
#                                                    protein_percentage
# item_code item                       year origin
# 2734      Poultry Meat               2013 animal            12.341237
# 2731      Bovine Meat                2013 animal            11.315274
# 2733      Pigmeat                    2013 animal            10.015137
# 2763      Pelagic Fish               2013 animal             9.496129
# 2549      Pulses, Other and products 2013 vegetal            8.985490
# 2764      Marine Fish, Other         2013 animal             8.773284
# 2511      Wheat and products         2013 vegetal            7.620493
# 2736      Offals, Edible             2013 animal             6.747166
# 2556      Groundnuts (Shelled Eq)    2013 vegetal            6.529279
# 2744      Eggs                       2013 animal             6.449286
# 2805      Rice (Milled Equivalent)   2013 vegetal            6.409195
# 2555      Soyabeans                  2013 vegetal            5.855895
# 2762      Demersal Fish              2013 animal             5.741086
# 2547      Peas                       2013 vegetal            5.626240
# 2546      Beans                      2013 vegetal            5.362527
# 2732      Mutton & Goat Meat         2013 animal             4.518095
# 2735      Meat, Other                2013 animal             4.448258
# 2765      Crustaceans                2013 animal             4.147485
# 2514      Maize and products         2013 vegetal            3.441944
# 2848      Milk - Excluding Butter    2013 animal             3.427677

# %% [markdown]
# - Parmi les 20 aliments les plus riches en protéines, on peut citer:
#     les viandes & poissons, les lentilles, la farine, le soja, les noix

# %% [markdown]
# ## Question 6

# %%
vegetals = data[data['origin'] == "vegetal"]

# %% [markdown]
# ## Question 7

# %%
(vegetals['total_kcal'].sum()/(1819*365))/1000000000
# Out:
# 7.754478344145135

# %%
(vegetals['total_kcal'].sum()/(2500*365))/1000000000
# Out:
# 5.6421584432

# %% [markdown]
# - La disponibilité intérieure mondiale de produits végétaux permettrait de nourrir 7,75 milliards de personnes
# (à raison d'un apport de 1819 Calories nécessaires par jour et par personne pour assurer une activité physique légère et maintenir un poids minimum acceptable.) source: http://www.fao.org/3/i3434f/i3434f02.pdf
# - Et 5,6 milliards pour un apport moyen de 2500 Calories

# %%
(vegetals['total_kcal'].sum()/(2500*365)) / mondial_pop * 100
# Out:
# 80.63306530523231

# %% [markdown]
# - Soit 80,6% de la population mondiale

# %%
(vegetals['total_protein_kg'].sum()/(0.04*365))/1000000000
# Out:
# 8.601666658250002

# %% [markdown]
# - La disponibilité intérieure mondiale de protéines végétales est suffisante pour 8,6 milliards de personnes
# (à raison d'un apport moyen de 40g de protéines par jour et par personne) source: http://www.fao.org/3/x0081f/X0081F0p.htm

# %%
(vegetals['total_protein_kg'].sum()/(0.04*365))/ mondial_pop * 100
# Out:
# 122.92791072261036

# %% [markdown]
# - Soit 123 % de la population mondiale

# %% [markdown]
# ## Question 8

# %%
temp = vegetals.copy()
temp = temp.replace([np.inf, -np.inf], np.nan).dropna(subset=["kcal/kg"], how="all")
temp['total_food_kcal'] = (temp['food'] + temp['feed'] + temp['waste']) * 1000000 * temp['kcal/kg']
temp['total_food_kcal'].sum()/(2500*365)/1000000000
# Out:
# 6.726453395149421

# %% [markdown]
# - En additionant, les quantités de nourriture d'origine végétale destinées à l'alimentation humaine et animale avec la nourriture gaspillée, on pourrait nourrir 6,7 milliards de personnes

# %%
(temp['total_food_kcal'].sum()/(2500*365)) / mondial_pop * 100
# Out:
# 96.12891260389212

# %% [markdown]
# - Soit 96,1 % de la population mondiale

# %% [markdown]
# ## Question 9

# %%
temp = data.copy()
temp = temp.replace([np.inf, -np.inf], np.nan).dropna(subset=["kcal/kg"], how="all")
temp['total_food_kcal'] = (temp['food']) * 1000000 * temp['kcal/kg']
temp['total_food_kcal'].sum()/(2500*365)/1000000000
# Out:
# 7.087250976795807

# %%
(temp['total_food_kcal'].sum()/(2500*365)) / mondial_pop *100
# Out:
# 101.285133446631

# %% [markdown]
# - Soit un peu plus de la totalité des êtres humains sur la planète !

# %% [markdown]
# ## Question 10

# %%
df10 = pd.read_csv("Q10.csv", usecols = ["Produit", "Valeur"])

# %%
(df10['Valeur'] * 1000 / pop['total_population'].sum()) * 100
# Out:
# 0    11.67829
# Name: Valeur, dtype: float64

# %% [markdown]
# - Le pourcentage de la population mondiale en situation de sous-nutrition est de 11.7 %

# %% [markdown]
# ## Question 11

# %%
# Liste des codes produit classés par la FAO dans la catégorie Céréales
cereals = [2511, 2513, 2514, 2515, 2516, 2517, 2518, 2520, 2805]

for item_code in cereals:
    data['is_cereal'] = np.where(data['item_code'] == item_code, True, False)

# Test if values have been updated as wanted
data.query('item_code == 2805')
# Out:
#        country_code                             country  item_code  \
# 87                1                             Armenia       2805
# 147               2                         Afghanistan       2805
# 239               3                             Albania       2805
# 503                NaN                            0.52      NaN  ...
# 596              561.0                            0.23      NaN  ...
# 691              488.0                            0.18      NaN  ...
# 786                4.0                            0.07      0.0  ...
# 876                0.0                            0.49      NaN  ...
# 968                0.0                            0.60      0.0  ...
# 1062               1.0                            3.78   1031.0  ...
# 1143               NaN                            0.13      NaN  ...
# 1236               2.0                            0.47      3.0  ...
# 1330              10.0                            0.14      NaN  ...
# 1426             814.0                            0.54      NaN  ...
# 1515               0.0                            0.45      NaN  ...
# 1593               0.0                            1.36      0.0  ...
# 1688               0.0                            1.84      7.0  ...
# 1781              41.0                            0.12      5.0  ...
# 1866             512.0                            5.50   7882.0  ...
# 1960               1.0                            0.23      NaN  ...
# 2056             140.0                            0.25      NaN  ...
# 2138               0.0                            0.67      NaN  ...
# 2223               0.0                            0.11      NaN  ...
# 2318              11.0                            1.43      0.0  ...
# 2391               0.0                            0.15      NaN  ...
# 2484               0.0                            0.14      NaN  ...
# 2580               0.0                            0.47     29.0  ...
# 2669               0.0                            0.23      NaN  ...
# ...                ...                             ...      ...  ...
# 12989              1.0                            0.05    100.0  ...
# 13047              NaN                            0.21      NaN  ...
# 13140             10.0                            0.85     65.0  ...
# 13236             53.0                            0.29      NaN  ...
# 13331           6860.0                            2.50   2405.0  ...
# 13421              6.0                            0.90      NaN  ...
# 13512              6.0                            0.67      1.0  ...
# 13606             16.0                            1.08      1.0  ...
# 13698              0.0                            0.01      NaN  ...
# 13791              9.0                            0.21      NaN  ...
# 13883            272.0                            1.08      2.0  ...
# 13978             71.0                            0.07      NaN  ...
# 14073            205.0                            0.13      7.0  ...
# 14164             21.0                            0.06      NaN  ...
# 14259           3522.0                            0.08      NaN  ...
# 14347              3.0                            0.30     34.0  ...
# 14440            879.0                            0.21      NaN  ...
# 14523              0.0                            0.07      2.0  ...
# 14619              0.0                            0.37    260.0  ...
# 14700           6951.0                            4.60   2712.0  ...
# 14791              0.0                            0.04      NaN  ...
# 14867              0.0                            0.13      NaN  ...
# 14960              2.0                            0.34      NaN  ...
# 15053              0.0                            0.05      NaN  ...
# 15148            276.0                            0.19     64.0  ...
# 15241              0.0                            0.12      0.0  ...
# 15333              1.0                            0.03      NaN  ...
# 15422              0.0                            0.04      NaN  ...
# 15506              NaN                            0.05      NaN  ...
# 15603            565.0                            2.68  12117.0  ...
#
#        production  protein_supply_quantity_gcapitaday    seed  \
# 87            NaN                                0.66     NaN
# 147         342.0                                2.70    14.0
# 239           0.0                                1.34     0.0
# 332           0.0                                0.57     0.0
# 412          25.0                                1.56     1.0
# 503           NaN                                2.28     NaN
# 596        1043.0                                1.81    26.0
# 691         774.0                                1.93     8.0
# 786           NaN                                0.68     NaN
# 876           NaN                                4.85     NaN
# 968           NaN                                3.48     NaN
# 1062      34350.0                               32.14   788.0
# 1143          NaN                                1.01     NaN
# 1236        295.0                                5.65     7.0
# 1330          NaN                                1.27     NaN
# 1426       7843.0                                6.44   120.0
# 1515         14.0                                5.47     0.0
# 1593          3.0                               10.90     0.0
# 1688          1.0                               13.56     0.0
# 1781         37.0                                0.54     2.0
# 13236  3544.026654            0.138242       True
# 13331  3628.654971            0.094947       True
# 13421  3595.228934            1.127994       True
# 13512  3988.705739            6.105455       True
# 13606  3601.591512            1.848146       True
# 13698  3752.336449            0.638750       True
# 13791  3296.554935            0.076627       True
# 13883  3601.333333            0.716816       True
# 13978  3539.870690            0.182500       True
# 14073  3884.194053            0.115358       True
# 14164  3528.333333            0.146000       True
# 14259  3819.767442            0.022036       True
# 14347  3525.664956            0.394160       True
# 14440  3681.739130            2.143205       True
# 14523  3489.664083            0.224866       True
# 14619  3495.510902            0.227419       True
# 14700  3509.615385            0.078051       True
# 14791  3568.888889            0.068868       True
# 14867  3759.136213           40.150000       True
# 14960  3721.486175            0.292689       True
# 15053  3590.163934            0.472841       True
# 15148  3815.331010            0.615938       True
# 15241  3823.809524           15.330000       True
# 15333  3590.163934            0.699583       True
# 15422  3584.821429           15.330000       True
# 15506  4023.622047            0.212917       True
# 15603  3756.036152            0.004813       True
#
# [174 rows x 27 columns]

# %%
data.query('item_code == 2543')
# Out:
#        country_code                             country  item_code  \
# 520               9                           Argentina       2543
# 710              11                             Austria       2543
# 1349             21                              Brazil       2543
# 1705             27                            Bulgaria       2543
# 1979             33                              Canada       2543
# 2241             38                           Sri Lanka       2543
# 2408             40                               Chile       2543
# 2689             48                          Costa Rica       2543
# 3406             57                             Belarus       2543
# 3969             67                             Finland       2543
# 4064             68                              France       2543
# 4596             79                             Germany       2543
# 4688             80              Bosnia and Herzegovina       2543
# 4947             84                              Greece       2543
# 5580             96                China, Hong Kong SAR       2543
# 5767             98                             Croatia       2543
# 5952            100                               India       2543
# 6048            101                           Indonesia       2543
# 6143            102          Iran (Islamic Republic of)       2543
# 6321            104                             Ireland       2543
# 6507            106                               Italy       2543
# 6789            109                             Jamaica       2543
# 6884            110                               Japan       2543
# 7408            117                   Republic of Korea       2543
# 7592            119                              Latvia       2543
# 7971            126                           Lithuania       2543
# 8153            129                          Madagascar       2543
# 8338            131                            Malaysia       2543
# 8885            138                              Mexico       2543
# 10252           162                              Norway       2543
# 10347           165                            Pakistan       2543
# 10441           166                              Panama       2543
# 10535           167                             Czechia       2543
# 10628           169                            Paraguay       2543
# 10818           171                         Philippines       2543
# 10910           173                              Poland       2543
# 11325           183                             Romania       2543
# 11930           194                        Saudi Arabia       2543
# 12292           199                            Slovakia       2543
# 12387           202                        South Africa       2543
# 12482           203                               Spain       2543
# 12913           211                         Switzerland       2543
# 13065           214           China, Taiwan Province of       2543
# 13255           216                            Thailand       2543
# 13439           220                 Trinidad and Tobago       2543
# 13716           223                              Turkey       2543
# 13997           229                      United Kingdom       2543
# 14183           231            United States of America       2543
# 14365           234                             Uruguay       2543
# 14543           236  Venezuela (Bolivarian Republic of)       2543
# 15072           255                             Belgium       2543
# 15526           351                               China       2543
#
#                     item  year   origin  domestic_supply_quantity  \
# 520    Sweeteners, Other  2013  vegetal                     279.0
# 710    Sweeteners, Other  2013  vegetal                     294.0
# 1349   Sweeteners, Other  2013  vegetal                     142.0
# 1705   Sweeteners, Other  2013  vegetal                      40.0
# 2408              12.0                             NaN   NaN  ...         NaN
# 2689               0.0                             NaN   NaN  ...         NaN
# 3406               1.0                             NaN   NaN  ...         1.0
# 3969               5.0                             NaN   NaN  ...        15.0
# 4064             342.0                             NaN  28.0  ...      1341.0
# 4596             697.0                             NaN   NaN  ...       609.0
# 4688              36.0                             NaN   0.0  ...        19.0
# 4947              15.0                             NaN   NaN  ...        35.0
# 5580               3.0                            0.14   NaN  ...         1.0
# 5767             243.0                             NaN   0.0  ...        91.0
# 5952             161.0                             NaN   NaN  ...       301.0
# 6048              63.0                            0.07   NaN  ...       440.0
# 6143               2.0                             NaN   NaN  ...         NaN
# 6321              28.0                             NaN   NaN  ...         5.0
# 6507             340.0                             NaN   NaN  ...       355.0
# 6789               3.0                             NaN   NaN  ...         NaN
# 6884              17.0                             NaN   NaN  ...      1275.0
# 7408             236.0                             NaN   NaN  ...       849.0
# 7592              10.0                             NaN   NaN  ...         1.0
# 7971              36.0                             NaN   4.0  ...        36.0
# 8153               0.0                             NaN   NaN  ...         9.0
# 8338              98.0                            0.02   NaN  ...        42.0
# 8885             148.0                             NaN   NaN  ...       220.0
# 10252              9.0                             NaN   NaN  ...         4.0
# 10347             40.0                             NaN   NaN  ...        57.0
# 10441              0.0                             NaN   NaN  ...         1.0
# 10535             95.0                             NaN   NaN  ...        54.0
# 10628              0.0                            0.00   NaN  ...         NaN
# 10818             13.0                            0.04   NaN  ...         NaN
# 10910            154.0                             NaN   NaN  ...       105.0
# 11325             38.0                             NaN   NaN  ...        39.0
# 11930             35.0                             NaN   NaN  ...         NaN
# 12292            231.0                             NaN   NaN  ...       220.0
# 12387             42.0                             NaN   NaN  ...        77.0
# 12482            142.0                             NaN   NaN  ...        79.0
# 12913            154.0                             NaN   NaN  ...        33.0
# 13065             84.0                             NaN   NaN  ...       123.0
# 13255             62.0                             NaN   NaN  ...       117.0
# 13439              0.0                             NaN   NaN  ...         NaN
# 13716            162.0                             NaN   NaN  ...        72.0
# 13997            183.0                             NaN   NaN  ...       307.0
# 14183           2731.0                             NaN   NaN  ...     12775.0
# 14365              0.0                             NaN   NaN  ...         1.0
# 14543              0.0                             NaN   NaN  ...         NaN
# 15072            339.0                             NaN   NaN  ...        28.0
# 15526           1173.0                            0.00   NaN  ...      1201.0
#
#        protein_supply_quantity_gcapitaday  seed  stock_variation  \
# 520                                  0.01   NaN              0.0
# 710                                  0.01   NaN              0.0
# 1349                                 0.00   NaN              NaN
# 1705                                 0.00   NaN              0.0
# 1979                                 0.01   NaN              0.0
# 2241                                 0.00   NaN              1.0
# 2408                                 0.00   NaN              0.0
# 2689                                 0.00   NaN              0.0
# 3406                                 0.00   NaN              NaN
# 3969                                 0.00   NaN              0.0
# 4064                                 0.00   NaN              0.0
# 4596                                 0.00   NaN              0.0
# 4688                                 0.00   NaN              NaN
# 4947                                 0.00   NaN              0.0
# 5580                                 0.04   NaN              0.0
# 5767                                 0.03   NaN             12.0
# 5952                                 0.00   NaN              0.0
# 6048                                 0.02   NaN              0.0
# 6143                                 0.00   NaN              0.0
# 6321                                 0.00   NaN              0.0
# 6507                                 0.00   NaN              0.0
# 6789                                 0.00   NaN              0.0
# 6884                                 0.08   NaN              NaN
# 7408                                 0.11   NaN             30.0
# 7592                                 0.00   NaN              0.0
# 7971                                 0.00   NaN              5.0
# 8153                                 0.00   NaN              NaN
# 8338                                 0.01   NaN              7.0
# 8885                                 0.08   NaN              0.0
# 10252                                0.00   NaN              0.0
# 10347                                0.00   NaN              0.0
# 10441                                0.01   NaN              0.0
# 10535                                0.01   NaN              0.0
# 10628                                0.00   NaN              NaN
# 10818                                0.01   NaN              0.0
# 10910                                0.00   NaN              0.0
# 11325                                0.01   NaN            -15.0
# 11930                                0.00   NaN              0.0
# 12292                                0.03   NaN              0.0
# 12387                                0.00   NaN              0.0
# 12482                                0.00   NaN              8.0
# 12913                                0.00   NaN             36.0
# 13065                                0.00   NaN              1.0
# 13255                                0.00   NaN              0.0
# 13439                                0.00   NaN              0.0
# 13716                                0.00   NaN              7.0
# 13997                                0.00   NaN              1.0
# 14183                                0.17   NaN            -25.0
# 14365                                0.02   NaN              0.0
# 14543                                0.00   NaN              NaN
# 15072                                0.01   NaN              NaN
# 15526                                0.00   NaN              1.0
#
#        total_population    total_kcal  total_protein_kg      kcal/kg  \
# 520               41446  9.984341e+11         151277.90  3579.494799
# 710                8495  1.116243e+11          31006.75  2939.597315
# 1349             200362  4.387928e+11              0.00  3268.656716
# 1705               7223  3.954592e+10              0.00  2310.126582
# 1979              35182  1.219936e+12         128414.30  2284.255599
# 2241              21273  3.105858e+10              0.00  4055.555556
# 2408              17620  1.414886e+11              0.00  2788.194444
# 2689               4872  3.200904e+10              0.00  3386.597938
# 3406               9357  4.098366e+10              0.00  3532.258065
# 3969               5426  4.753176e+10              0.00  2546.511628
# 4064              64291  2.581284e+11              0.00  2048.469388
# 4596              82727  3.502661e+12              0.00  3576.013514
# 4688               3829  2.795170e+10              0.00  1689.814815
# 4947              11128  3.249376e+10              0.00  2263.565891
# 5580               7204  6.836596e+10         105178.40  3707.031250
# 5767               4290  1.033461e+11          46975.50  2656.008820
# 5952            1252140  4.570311e+11              0.00  3041.666667
# 6048             249866  1.276815e+12        1824021.80  3452.702703
# 6143              77447  2.826816e+10              0.00  2281.250000
# 6321               4627  2.026626e+11              0.00  2480.181200
# 6507              60990  1.780908e+11              0.00  2317.460317
# 6789               2784  2.642016e+10              0.00  2137.387387
# 6884             127144  4.037458e+12        3712604.80  3018.536122
# 7408              49263  2.355510e+12        1977909.45  2964.352139
# 7592               2050  5.911175e+10              0.00  2538.292254
# 7971               3017  9.470363e+10              0.00  2306.392359
# 8153              22925  8.367625e+09              0.00   760.416667
# 8338              29717  9.762034e+10         108467.05  2907.079646
# 8885             122332  3.884653e+12        3572094.40  3047.504798
# 10252              5043  4.049529e+10              0.00   523.127036
# 10347            182143  6.648220e+10              0.00  2147.058824
# 10441              3864  3.243828e+10          14103.60  3120.817844
# 10535             10702  1.523430e+11          39062.30  2099.557522
# 10628              6802  1.241365e+10              0.00  1921.052632
# 10818             98394  4.309657e+11         359138.10  2517.241379
# 10910             38217  6.974602e+10              0.00  2607.142857
# 11325             21699  1.663228e+11          79201.35  3128.571429
# 11930             28829  2.104517e+10              0.00  3476.190476
# 12292              5450  1.770432e+11          59677.50  2237.258953
# 12387             52776  2.504221e+11              0.00  2807.692308
# 12482             46927  8.564178e+10              0.00  2683.823529
# 12913              8078  9.140257e+10              0.00  3125.690608
# 13065             23330  2.214017e+11              0.00  3261.168385
# 13255             67011  5.136393e+11              0.00  3516.055046
# 13439              1341  1.468395e+10              0.00  3590.163934
# 13716             74933  2.735054e+10              0.00  2281.250000
# 13997             63384  2.776219e+11              0.00  2281.250000
# 14183            320051  3.212512e+13       19859164.55  3198.693435
# 14365              3407  7.834396e+10          24871.10  2936.781609
# 14543             30405  8.878260e+10              0.00  3318.181818
# 15072             11104  9.321808e+10          40529.60  2215.039578
# 15526           1416667  5.170835e+11              0.00  2607.142857
#
#        protein_percentage  is_cereal
# 520              0.001308      False
# 710              0.009605      False
# 1349             0.000000      False
# 1705             0.000000      False
# 1979             0.000684      False
# 2241             0.000000      False
# 2408             0.000000      False
# 2689             0.000000      False
# 3406             0.000000      False
# 3969             0.000000      False
# 4064             0.000000      False
# 4596             0.000000      False
# 4688             0.000000      False
# 4947             0.000000      False
# 5580             0.081111      False
# 5767             0.028077      False
# 5952             0.000000      False
# 6048             0.001973      False
# 6143             0.000000      False
# 6321             0.000000      False
# 6507             0.000000      False
# 6789             0.000000      False
# 6884             0.002184      False
# 7408             0.005057      False
# 7592             0.000000      False
# 7971             0.000000      False
# 8153             0.000000      False
# 8338             0.010735      False
# 8885             0.002292      False
# 10252            0.000000      False
# 10347            0.000000      False
# 10441            0.036500      False
# 10535            0.005000      False
# 10628            0.000000      False
# 10818            0.002135      False
# 10910            0.000000      False
# 11325            0.006887      False
# 11930            0.000000      False
# 12292            0.013861      False
# 12387            0.000000      False
# 12482            0.000000      False
# 12913            0.000000      False
# 13065            0.000000      False
# 13255            0.000000      False
# 13439            0.000000      False
# 13716            0.000000      False
# 13997            0.000000      False
# 14183            0.000618      False
# 14365            0.027037      False
# 14543            0.000000      False
# 15072            0.008690      False
# 15526            0.000000      False
#
# [52 rows x 27 columns]

# %%
temp = data[data['is_cereal'] == True]

temp['feed'].sum() / (temp['feed'].sum() + temp['food'].sum()) * 100
# Out:
# 8.162745635371978

# %% [markdown]
# - La part de l'alimentation en céréales destinée aux animaux est de 8,2% de l'alimentation totale

# %% [markdown]
# ## Question 14

# %% [markdown]
# - En thaïlande, 6,1 millions de personnes sont sous alimentées en 2013

# %%
pop.query('country == "Thailand"')
# Out:
#                                                  total_population
# country_code country  item_code item       year
# 216          Thailand 2501      Population 2013             67011

# %%
(6100000/(67011000)) * 100
# Out:
# 9.102983092328126

# %% [markdown]
# - Soit 9.1 % de la population de ce pays.

# %%
temp = data[data['item'].str.contains("Cassava")]

# %%
temp = temp.query('country == "Thailand"')

# %%
temp['export_quantity'] / temp['production'] * 100
# Out:
# 13248    83.41273
# dtype: float64

# %% [markdown]
# - La proportion de manioc exportée de Thaïlande est de 83.4 %
